# %%
import numpy as np #matematik işlemeri, lineer cebir
import pandas as pd  #dataframe, matris işlemleri 
import os #işletim sistemi

# %%
#veri yolu verilip
data_path = '/home/ebru/Desktop/NLP/NLP_project/data/'
print('Available data', os.listdir(data_path))
#ayrı klasör içinden ayrı ayrı veriler çağıracağımız için veriyolu ekleyip döngü ile veri çağırabileceğimiz fonksiyon tanımlandı 
#text dosyaları ubuntuda encoding="Windows-1254",  windowsda encoding="utf-8" ile açılabilmiştir.
def read_data(partition):
    data = []
    for fn in os.listdir(os.path.join(data_path, partition)):
        text = open(os.path.join(data_path, partition, fn),'r',encoding="Windows-1254").read()
        data.append(text)
    return data
# Out:
# Available data ['kadın', 'erkek']

# %%
#kadın ve erkek klasör isimleri path olarak verilerek fonksiyon ile veri okundu/yüklendi
df_kadin = read_data('kadın')
df_erkek = read_data('erkek')
df_kadin
# Out:
# ["Boğaziçi Üniversitesi’nin zengin çocuklarının gittiği bir okul olduğu fikri ne zaman ortaya çıktı bilmiyorum. Belki de Robert Kolej zamanından kalma bir önyargıdır bu.\n\nNe zaman Boğaziçi’nde hak talep eden bir eylem yapılsa, herkes bir ağızdan bunun esas meselelere temas etmeyen tali bir şey olduğunu söylemek için sıraya girer. Onlara göre, Boğaziçi’nin ayrıcalıklı ve şımarık öğrencileri böyle “artistlik” yapmamalı, mümkünse asıl ait oldukları yere, yani partilerle konserlere falan gitmelidir.\n\nBu garip argüman, pek sevilmiş olsa gerek ki, senelerdir kullanılır. Boğaziçi Üniversitesi öğrencilerine eylem yapmayı, okulları üzerinde hak talep etmeyi, başka üniversitelerin öğrencileri ile dayanışmayı yakıştıramazlar bir türlü. Sonuçta onlar bir avuç zengin çocuğudur. Fazla konuşmasınlar, devletin iyi üniversitelerinden birinde oldukları için şükretsinler, oturup derslerine çalışsınlardır.\n\nGeçtiğimiz salı günü Boğaziçili bir grup öğrenci, okulun orta yerinde birdenbire peydah ola
# ...

# %%
#veri dataframe e çevrildi
df_kadin = pd.DataFrame(df_kadin, columns =['text'])
df_kadin.tail()
# Out:
#                                                   text
# 245  Bugün o gündür!\n\nİclal Aydın - iclal@gazetev...
# 246  Ne zaman bir öğrenciyle karşılaşsa öğrencilik ...
# 247  Genel seçimler yaklaşıyor. Binlerce milletveki...
# 248  Bir ‘Şiir Okulu’ sahibi olmak. Bir şair için n...
# 249  Keşke hiç militarist resmî geçitler olmasa. Sa...

# %%
#veri dataframe e çevrildi
df_erkek = pd.DataFrame(df_erkek, columns =['text'])
df_erkek.tail()
# Out:
#                                                   text
# 245  Aptal yerine konmanın bu kadarı da olmaz\n\nCa...
# 246  İlk Üç Madde\n15 Ekim 2011 - Cumhuriyet\n1982 ...
# 247  Bebek ağlaması\n\nİnsanı en çaresiz bırakan an...
# 248  AKP’nin işine gelmezse Özel Yetkili Savcılık k...
# 249  Bugün 12 Eylül\nBugün 12 Eylül 1980 darbesinin...

# %%
#kadın için 250 tane female etketi oluşturuldu
label_kadin=[]
for x in range(250):
  label_kadin.append('female')
label_kadin
# Out:
# ['female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
# ...

# %%
#erkek için 250 tane male etketi oluşturuldu
label_erkek=[]
for x in range(250):
  label_erkek.append('male')
label_erkek
# Out:
# ['male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
# ...

# %%
#etiket dataframe e çevrildi
label_erkek = pd.DataFrame(label_erkek, columns =['label'])
label_erkek.head()
# Out:
#   label
# 0  male
# 1  male
# 2  male
# 3  male
# 4  male

# %%
#etiket dataframe e çevrildi
label_kadin = pd.DataFrame(label_kadin, columns =['label'])
label_kadin.head()
# Out:
#     label
# 0  female
# 1  female
# 2  female
# 3  female
# 4  female

# %%
#kadın text dataframe ve kadın label dataframe leri birleştirildi
df1=pd.concat([df_kadin,label_kadin], axis=1)
df1.head()
# Out:
#                                                 text   label
# 0  Boğaziçi Üniversitesi’nin zengin çocuklarının ...  female
# 1  Eksik\n\nİclal Aydın - iclal@gazetevatan.com\n...  female
# 2  Uçağa binmeden  yazıyı yetiştireyim demiştim a...  female
# 3  Somali’de çocukların öldüğü, insanların açlıkt...  female
# 4  Ben neden şimdi öğrendim anne?\n\nİclal Aydın ...  female

# %%
#erkek text dataframe ve erkek label dataframe leri birleştirildi
df2=pd.concat([df_erkek,label_erkek], axis=1)
df2.head()
# Out:
#                                                 text label
# 0  Cumhuriyet Aydını Hazırlıksız Yakalandı\n11 Şu...  male
# 1  Sahnelerden birkaç izlenim\nKardan eve kapandı...  male
# 2  Menderes'i imarcı olarak anmak\nCuma günüm hem...  male
# 3  28 Şubat askeri değil ekonomik operasyondu\n\n...  male
# 4  Çok almak!\n\nNe zaman içinde çok geçen bir cü...  male

# %%
#wordcloud ta kullanmak için cinsiyetler ayrı ayrı csv yapıldı
df1.to_csv("kadin.csv")
df2.to_csv("erkek.csv")

# %%
#kadın ve erkek dataframeleri birleştirildi
data = pd.concat([df1, df2], ignore_index=True)
data.tail()
# Out:
#                                                   text label
# 495  Aptal yerine konmanın bu kadarı da olmaz\n\nCa...  male
# 496  İlk Üç Madde\n15 Ekim 2011 - Cumhuriyet\n1982 ...  male
# 497  Bebek ağlaması\n\nİnsanı en çaresiz bırakan an...  male
# 498  AKP’nin işine gelmezse Özel Yetkili Savcılık k...  male
# 499  Bugün 12 Eylül\nBugün 12 Eylül 1980 darbesinin...  male

# %%
#analizde kullanılacak veriseti kaydedildi
data.to_csv("dataall.csv")
